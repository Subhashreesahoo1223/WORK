# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
# load in the dataset into a pandas dataframe
diamonds = pd.read_csv(r'C:\Users\subhashree\Downloads\Data-Analytics-Projects-master\Data-Analytics-Projects-master\Data Visulization with Diamond Data Set\diamonds.csv',encoding = 'ISO-8859-1')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %%
diamonds.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamonds.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
diamonds.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000214AA89B608>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB43AB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB474A48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB4ACB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB4E4C08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB51CD48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB554E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB58EF48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000214AB599B48>]],
#       dtype=object)

# %%
bin_edges = np.arange(0 , diamonds['carat'].max()+0.1 , 0.1)
plt.hist(data = diamonds , x = 'carat', bins = bin_edges);
plt.xlim(0,3)
# Out:
# (0, 3)

# %%
diamonds.color.value_counts().plot(kind='bar')

# %%
diamonds.cut.value_counts().plot(kind='bar')

# %%
diamonds.clarity.value_counts().plot(kind='bar')

# %%
# bivariate plot of price vs. carat 
# numeric variable and numeric variable : scatter plot
base_color = sb.color_palette()[0]
plt.scatter(data = diamonds , x = 'carat' , y = 'price')

# %%
# bivariate plots of price vs. cut, color, clarity
# numeric variable and categorical variable : violin plot or box plot 
base_color = sb.color_palette()[0]
sb.boxplot(data = diamonds , x = 'cut', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
base_color = sb.color_palette()[0]
sb.boxplot(data = diamonds , x = 'color', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
base_color = sb.color_palette()[0]
sb.boxplot(data = diamonds , x = 'clarity', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data = diamonds , x = 'cut', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data = diamonds , x = 'color', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data = diamonds , x = 'clarity', y='price', color=base_color)
plt.xticks(rotation = 15)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text xticklabel objects>)

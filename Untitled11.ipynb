# %%
import pandas as pd

# %%
job=pd.read_csv(r'C:\Users\subhashree\Downloads\archive (3)\DataAnalyst.csv')

# %%
job=pd.read_csv(r'C:\Users\subhashree\Downloads\archive (3)\DataAnalyst.csv')
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
job.isnull().sum()
# Out:
# Unnamed: 0           0
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         1
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# Easy Apply           0
# dtype: int64

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# ...

# %%
job.shape
# Out:
# (2253, 16)

# %%
job.nunique()
# Out:
# Unnamed: 0           2253
# Job Title            1272
# Salary Estimate        90
# Job Description      2253
# Rating                 37
# Company Name         1513
# Location              253
# Headquarters          483
# Size                    9
# Founded               161
# Type of ownership      15
# Industry               89
# Sector                 25
# Revenue                14
# Competitors           291
# Easy Apply              2
# dtype: int64

# %%
job['Rating'].median()
# Out:
# 3.6

# %%
job_high_rated=job[job.Rating >=job['Rating'].median()]
job_low_rated=job[job.Rating <job['Rating'].median()]

# %%
job_high_rated
# Out:
#       Unnamed: 0                                          Job Title  \
# 1              1                               Quality Data Analyst
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# 5              5                                       Data Analyst
# 6              6                       Business/Data Analyst (FP&A)
# ...          ...                                                ...
# 2234        2234   Data Analyst 3, Customer Experience - Centennial
# 2235        2235                       Data Base Programmer/Analyst
# 2236        2236                   Senior Health Data Analyst (SAS)
# 2238        2238                       Senior Contract Data Analyst
# 2247        2247  Marketing/Communications - Data Analyst-Marketing
#
#                   Salary Estimate  \
# 1      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...

# %%
job_high_rated.nunique()
# Out:
# Unnamed: 0           1226
# Job Title             728
# Salary Estimate        88
# Job Description      1226
# Rating                 15
# Company Name          756
# Location              168
# Headquarters          297
# Size                    8
# Founded               123
# Type of ownership      13
# Industry               68
# Sector                 23
# Revenue                13
# Competitors           171
# Easy Apply              2
# dtype: int64

# %%
job['Salary Estimate'].unique()
# Out:
# array(['$37K-$66K (Glassdoor est.)', '$46K-$87K (Glassdoor est.)',
#        '$51K-$88K (Glassdoor est.)', '$51K-$87K (Glassdoor est.)',
#        '$59K-$85K (Glassdoor est.)', '$43K-$76K (Glassdoor est.)',
#        '$60K-$110K (Glassdoor est.)', '$41K-$78K (Glassdoor est.)',
#        '$45K-$88K (Glassdoor est.)', '$73K-$127K (Glassdoor est.)',
#        '$84K-$90K (Glassdoor est.)', '$27K-$52K (Glassdoor est.)',
#        '$42K-$74K (Glassdoor est.)', '$77K-$132K (Glassdoor est.)',
#        '$98K-$114K (Glassdoor est.)', '$48K-$96K (Glassdoor est.)',
#        '$26K-$47K (Glassdoor est.)', '$31K-$59K (Glassdoor est.)',
#        '$47K-$81K (Glassdoor est.)', '$43K-$69K (Glassdoor est.)',
#        '$49K-$112K (Glassdoor est.)', '$30K-$54K (Glassdoor est.)',
#        '$55K-$103K (Glassdoor est.)', '$37K-$70K (Glassdoor est.)',
#        '$57K-$103K (Glassdoor est.)', '$35K-$45K (Glassdoor est.)',
#        '$42K-$66K (Glassdoor est.)', '$65K-$81K (Glassdoor est.)',
# ...

# %%
job.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
# ...

# %%
job['Salary Estimate']
# Out:
# 0        $37K-$66K (Glassdoor est.)
# 1        $37K-$66K (Glassdoor est.)
# 2        $37K-$66K (Glassdoor est.)
# 3        $37K-$66K (Glassdoor est.)
# 4        $37K-$66K (Glassdoor est.)
#                    ...
# 2248    $78K-$104K (Glassdoor est.)
# 2249    $78K-$104K (Glassdoor est.)
# 2250    $78K-$104K (Glassdoor est.)
# 2251    $78K-$104K (Glassdoor est.)
# 2252    $78K-$104K (Glassdoor est.)
# Name: Salary Estimate, Length: 2253, dtype: object

# %%
job['Salary Estimate']=job['Salary Estimate'].replace('(Glassdoor est.)', '',inplace = True)

# %%
job['Salary Estimate']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2248    None
# 2249    None
# 2250    None
# 2251    None
# 2252    None
# Name: Salary Estimate, Length: 2253, dtype: object

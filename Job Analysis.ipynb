# %%
import pandas as pd

# %%
job=pd.read_csv(r'C:\Users\subhashree\Downloads\archive (3)\DataAnalyst.csv')

# %%
job.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
job['Salary Estimate']
# Out:
# 0        $37K-$66K (Glassdoor est.)
# 1        $37K-$66K (Glassdoor est.)
# 2        $37K-$66K (Glassdoor est.)
# 3        $37K-$66K (Glassdoor est.)
# 4        $37K-$66K (Glassdoor est.)
#                    ...
# 2248    $78K-$104K (Glassdoor est.)
# 2249    $78K-$104K (Glassdoor est.)
# 2250    $78K-$104K (Glassdoor est.)
# 2251    $78K-$104K (Glassdoor est.)
# 2252    $78K-$104K (Glassdoor est.)
# Name: Salary Estimate, Length: 2253, dtype: object

# %%
#src.insert(2,"Average Salary",0)

#calculating avg salary
def avg_sal(x):
    x = x.replace("(Glassdoor est.)","")
    x = x.replace("$","")
    x = x.replace("K","000")
    if x.find("0-")!=-1:
        avg = (int(x.split("-")[0])+int(x.split("-")[1]))/2
    else:
        avg=0
    return avg
print(avg_sal)
# Out:
# <function avg_sal at 0x000002C8CD4D7E58>

# %%
job.insert(2,"Average Salary",0)
job["Average Salary"] = job["Salary Estimate"].apply(avg_sal)

# %%
job
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#       Average Salary              Salary Estimate  \
# 0            51500.0   $37K-$66K (Glassdoor est.)
# 1            51500.0   $37K-$66K (Glassdoor est.)
# 2            51500.0   $37K-$66K (Glassdoor est.)
# 3            51500.0   $37K-$66K (Glassdoor est.)
# 4            51500.0   $37K-$66K (Glassdoor est.)
# ...              ...                          ...
# 2248         91000.0  $78K-$104K (Glassdoor est.)
# 2249         91000.0  $78K-$104K (Glassdoor est.)
# 2250         91000.0  $78K-$104K (Glassdoor est.)
# 2251         91000.0  $78K-$104K (Glassdoor est.)
# 2252         91000.0  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 17 columns]

# %%
job.drop(['Unnamed: 0','Salary Estimate'],axis=1,inplace=True)

# %%
job_high_rated=job[job.Rating >=job['Rating'].median()]
job_low_rated=job[job.Rating <job['Rating'].median()]

# %%
job.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          2253 non-null   object
#  1   Average Salary     2253 non-null   float64
#  2   Job Description    2253 non-null   object
#  3   Rating             2253 non-null   float64
#  4   Company Name       2252 non-null   object
#  5   Location           2253 non-null   object
#  6   Headquarters       2253 non-null   object
#  7   Size               2253 non-null   object
#  8   Founded            2253 non-null   int64
#  9   Type of ownership  2253 non-null   object
#  10  Industry           2253 non-null   object
#  11  Sector             2253 non-null   object
#  12  Revenue            2253 non-null   object
#  13  Competitors        2253 non-null   object
#  14  Easy Apply         2253 non-null   object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 264.1+ KB

# %%
job_high_rated_sal=job_high_rated[job_high_rated['Average Salary']>=job_high_rated['Average Salary'].median()]

# %%
job_high_rated_sal
# Out:
#                                               Job Title  Average Salary  \
# 60                      Data Analyst, Revenue Analytics         69500.0
# 61       Data Analyst - Data Acquisition / Data Lineage         69500.0
# 62       Data Analyst - Data Scanning utilizing Rochade         69500.0
# 63                             Data Analyst - Stitching         69500.0
# 64                                  Junior Data Analyst         69500.0
# ...                                                 ...             ...
# 2234   Data Analyst 3, Customer Experience - Centennial         78500.0
# 2235                       Data Base Programmer/Analyst         78500.0
# 2236                   Senior Health Data Analyst (SAS)         78500.0
# 2238                       Senior Contract Data Analyst         91000.0
# 2247  Marketing/Communications - Data Analyst-Marketing         91000.0
#
#                                         Job Description  Rating  \
# 60    About Ro\nFounded in 2017, Ro is a patient-dri...     4.8
# 61    OverviewAt Perficient you'll deliver mission-c...     3.6
# 62    OverviewAt Perficient you'll deliver mission-c...     3.6
# 63    OverviewAt Perficient you'll deliver mission-c...     3.6
# 64    RESPONSIBILITIES:\n\nKforce has a client in se...     4.1
# ...                                                 ...     ...
# 2234  Business Unit: Summary Responsible for working...     3.6
# 2235  Client is contracting for an on-site, temporar...     4.3
# 2236  Senior Health Data Analyst (SAS)\n\nTelligen i...     3.6
# 2238  Amyx is seeking to hire a Senior Contract Data...     4.0
# 2247  Job Description\nJob Title: Marketing/Communic...     4.1
#
#                          Company Name                         Location  \
# 60                            Ro\n4.8                     New York, NY
# 61                    Perficient\n3.6                     New York, NY
# 62                    Perficient\n3.6                     New York, NY
# 63                    Perficient\n3.6                     New York, NY
# 64                        Kforce\n4.1                     New York, NY
# ...                               ...                              ...
# 2234                     Comcast\n3.6                    Englewood, CO
# 2235       22nd Century Staffing\n4.3                       Denver, CO
# 2236                    Telligen\n3.6  Greenwood Village, Arapahoe, CO
# 2238                  Amyx, Inc.\n4.0                       Aurora, CO
# 2247  APN Software Services Inc.\n4.1                   Broomfield, CO
#
#              Headquarters                    Size  Founded  Type of ownership  \
# 60           New York, NY     51 to 200 employees     2017  Company - Private
# 61        Saint Louis, MO  1001 to 5000 employees     1998   Company - Public
# 62        Saint Louis, MO  1001 to 5000 employees     1998   Company - Public
# 63        Saint Louis, MO  1001 to 5000 employees     1998   Company - Public
# 64              Tampa, FL        10000+ employees     1966   Company - Public
# ...                   ...                     ...      ...                ...
# 2234     Philadelphia, PA        10000+ employees     1963   Company - Public
# 2235           McLean, VA     51 to 200 employees       -1  Company - Private
# 2236  West Des Moines, IA   501 to 1000 employees     1972  Company - Private
# 2238           Reston, VA   501 to 1000 employees     1999  Company - Private
# 2247           Newark, CA     51 to 200 employees       -1  Company - Private
#
#                               Industry                  Sector  \
# 60    Health Care Services & Hospitals             Health Care
# 61                         IT Services  Information Technology
# 62                         IT Services  Information Technology
# 63                         IT Services  Information Technology
# 64              Staffing & Outsourcing       Business Services
# ...                                ...                     ...
# 2234                                -1                      -1
# 2235            Staffing & Outsourcing       Business Services
# 2236  Health Care Services & Hospitals             Health Care
# 2238                       IT Services  Information Technology
# 2247      Computer Hardware & Software  Information Technology
#
#                                Revenue    Competitors Easy Apply
# 60            Unknown / Non-Applicable             -1         -1
# 61    $500 million to $1 billion (USD)             -1         -1
# 62    $500 million to $1 billion (USD)             -1         -1
# 63    $500 million to $1 billion (USD)             -1         -1
# 64              $1 to $2 billion (USD)             -1         -1
# ...                                ...            ...        ...
# 2234                $10+ billion (USD)  AT&T, Verizon         -1
# 2235           $5 to $10 million (USD)             -1       True
# 2236         $50 to $100 million (USD)             -1         -1
# 2238         $50 to $100 million (USD)             -1         -1
# 2247          $25 to $50 million (USD)             -1         -1
#
# [619 rows x 15 columns]

# %%
job_high_rated_sal.nunique()
# Out:
# Job Title            387
# Average Salary        37
# Job Description      619
# Rating                15
# Company Name         446
# Location             116
# Headquarters         207
# Size                   8
# Founded               90
# Type of ownership     12
# Industry              55
# Sector                22
# Revenue               13
# Competitors           99
# Easy Apply             2
# dtype: int64

# %%
max_sal = job_high_rated_sal.groupby(by=['Company Name', 'Job Title', 'Rating', 'Sector', 'Location'])['Average Salary']
#.sort_values(by=(['Rating', 'Max Salary']),ascending=False).head(10)

# %% [markdown]
# # Best jobs by Salary, Company Rating and Location

# %%
max_sal = job_high_rated.groupby(['Company Name', 'Job Title', 'Rating', 'Sector', 'Location'])['Average Salary'].median().reset_index()
max_sal.sort_values(by=(['Rating', 'Average Salary']),ascending=False).head(10)
# Out:
#                                Company Name  \
# 663                          Moveworks\n5.0
# 781                       Priceonomics\n5.0
# 1177                       Wilbur Labs\n5.0
# 900                        Softova Inc\n5.0
# 968   Staffigo Technical Services, LLC\n5.0
# 1071                Turn/River Capital\n5.0
# 554                LaBine & Associates\n5.0
# 801                        Quinn Group\n5.0
# 1156                     WB Technology\n5.0
# 931   Staffigo Technical Services, LLC\n5.0
#
#                                             Job Title  Rating  \
# 663                          AI Insights Data Analyst     5.0
# 781                               Data Studio Analyst     5.0
# 1177             Data Scientist/Analyst - Wilbur Labs     5.0
# 900                                      Data Analyst     5.0
# 968                               Junior Data Analyst     5.0
# 1071                          Operations Data Analyst     5.0
# 554   Sr Digital Marketing Data Analyst (PAID SOCIAL)     5.0
# 801                   Service Operations Data Analyst     5.0
# 1156                   Analyst, Financial Master Data     5.0
# 931                                      Data Analyst     5.0
#
#                       Sector              Location  Average Salary
# 663   Information Technology     Mountain View, CA        150000.0
# 781   Information Technology     San Francisco, CA        138500.0
# 1177  Information Technology     San Francisco, CA        138500.0
# 900   Information Technology         San Mateo, CA        126000.0
# 968   Information Technology     San Francisco, CA        126000.0
# 1071                 Finance     San Francisco, CA        126000.0
# 554        Business Services      Santa Monica, CA        122500.0
# 801                       -1  City of Industry, CA        122500.0
# 1156                      -1           Burbank, CA        122500.0
# 931   Information Technology          San Jose, CA        120000.0

# %%
max_sal.nunique()
# Out:
# Company Name      756
# Job Title         728
# Rating             15
# Sector             23
# Location          168
# Average Salary     75
# dtype: int64

# %%
max_sal.shape
# Out:
# (1224, 6)

# %% [markdown]
# # Location Visualization(Top 15)

# %%
max_sal['Location'].value_counts(ascending=False)[:15].plot(kind='bar')

# %%
max_sal['Sector']=max_sal['Sector'].replace('-1','None')

max_sal['Sector'].value_counts(ascending=False)[:15].plot(kind='bar')

# %%
max_sal.corr()
# Out:
#                  Rating  Average Salary
# Rating          1.00000         0.01754
# Average Salary  0.01754         1.00000

# %% [markdown]
# # Most wanted job Title

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
max_sal['Job Title'].value_counts()[:12].plot(kind='pie',autopct='%1.1f%%', labeldistance = None, pctdistance = 0.4, textprops={'fontsize': 10})
plt.legend( loc='best')
